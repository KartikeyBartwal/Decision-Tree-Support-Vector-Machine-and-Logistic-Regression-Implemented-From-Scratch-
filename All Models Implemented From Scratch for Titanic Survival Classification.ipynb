# %% [markdown]
# # Made By: Kartikey Bartwal
# ### https://www.linkedin.com/in/kartikey-bartwal-649088238/
# ### https://www.instagram.com/_._mr.kb_._/?next=%2F
# ### https://twitter.com/__mr__kb__

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("Titanic-Dataset.csv")

# %% [markdown]
# ## Exploratory Data Analysis

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# ### PassengerID

# %%
df["PassengerId"].describe()
# Out:
# count    891.000000
# mean     446.000000
# std      257.353842
# min        1.000000
# 25%      223.500000
# 50%      446.000000
# 75%      668.500000
# max      891.000000
# Name: PassengerId, dtype: float64

# %% [markdown]
# ### Survived

# %%
sns.countplot(x=df['Survived'])
# Out:
# <Axes: xlabel='Survived', ylabel='count'>

# %% [markdown]
# ### PClass

# %%
df["Pclass"].unique()
# Out:
# array([3, 1, 2], dtype=int64)

# %%
class_counts = df['Pclass'].value_counts()

# Create a pie chart
plt.figure(figsize=(8, 8))
plt.pie(class_counts, labels=class_counts.index, autopct='%1.1f%%', startangle=90)
plt.axis('equal')
plt.title('Passenger Class Distribution')
plt.show()

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %% [markdown]
# ### Name

# %%
'''Creating a wordcloud for name to help in the visualization'''
# Out:
# 'Creating a wordcloud for name to help in the visualization'

# %%
from wordcloud import WordCloud

# Generate word clouds for each unique name
unique_names = df['Name'].unique()
for name in unique_names:
    # Filter DataFrame for the specific name
    name_df = df[df['Name'] == name]
    
    # Concatenate all instances of the name into a single string
    text = ' '.join(name_df['Name'])
    
    # Create a word cloud
    wordcloud = WordCloud(width = 800, height = 800, 
                background_color ='white', 
                stopwords = None, 
                min_font_size = 10).generate(text)
    
    # Display the word cloud
    plt.figure(figsize = (8, 8), facecolor = None) 
    plt.imshow(wordcloud) 
    plt.axis("off") 
    plt.tight_layout(pad = 0) 
    
    # Save the word cloud to a file
    plt.savefig(f"{name}_wordcloud.png")
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[214], line 25
#      22 plt.tight_layout(pad = 0)
#      24 # Save the word cloud to a file
# ---> 25 plt.savefig(f"{name}_wordcloud.png")
#      26 plt.show()
#
# File c:\users\maste\appdata\local\programs\python\python39\lib\site-packages\matplotlib\pyplot.py:1134, in savefig(*args, **kwargs)
#    1131 fig = gcf()
#    1132 # savefig default implementation has no return, so mypy is unhappy
#    1133 # presumably this is here because subclasses can return?
# -> 1134 res = fig.savefig(*args, **kwargs)  # type: ignore[func-returns-value]
#    1135 fig.canvas.draw_idle()  # Need this if 'transparent=True', to reset colors.
#    1136 return res
#
# File c:\users\maste\appdata\local\programs\python\python39\lib\site-packages\matplotlib\figure.py:3390, in Figure.savefig(self, fname, transparent, **kwargs)
#    3388     for ax in self.axes:
#    3389         _recursively_make_axes_transparent(stack, ax)
# -> 3390 self.canvas.print_figure(fname, **kwargs)
#
# File c:\users\maste\appdata\local\programs\python\python39\lib\site-packages\matplotlib\backend_bases.py:2193, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2189 try:
#    2190     # _get_renderer may change the figure dpi (as vector formats
#    2191     # force the figure dpi to 72), so we need to set it again here.
#    2192     with cbook._setattr_cm(self.figure, dpi=dpi):
# -> 2193         result = print_method(
#    2194             filename,
#    2195             facecolor=facecolor,
#    2196             edgecolor=edgecolor,
#    2197             orientation=orientation,
#    2198             bbox_inches_restore=_bbox_inches_restore,
#    2199             **kwargs)
#    2200 finally:
#    2201     if bbox_inches and restore_bbox:
#
# File c:\users\maste\appdata\local\programs\python\python39\lib\site-packages\matplotlib\backend_bases.py:2043, in FigureCanvasBase._switch_canvas_and_return_print_method.<locals>.<lambda>(*args, **kwargs)
#    2039     optional_kws = {  # Passed by print_figure for other renderers.
#    2040         "dpi", "facecolor", "edgecolor", "orientation",
#    2041         "bbox_inches_restore"}
#    2042     skip = optional_kws - {*inspect.signature(meth).parameters}
# -> 2043     print_method = functools.wraps(meth)(lambda *args, **kwargs: meth(
#    2044         *args, **{k: v for k, v in kwargs.items() if k not in skip}))
#    2045 else:  # Let third-parties do as they see fit.
#    2046     print_method = meth
#
# File c:\users\maste\appdata\local\programs\python\python39\lib\site-packages\matplotlib\backends\backend_agg.py:497, in FigureCanvasAgg.print_png(self, filename_or_obj, metadata, pil_kwargs)
#     450 def print_png(self, filename_or_obj, *, metadata=None, pil_kwargs=None):
#     451     """
#     452     Write the figure to a PNG file.
#     453
#    (...)
#     495         *metadata*, including the default 'Software' key.
#     496     """
# --> 497     self._print_pil(filename_or_obj, "png", pil_kwargs, metadata)
#
# File c:\users\maste\appdata\local\programs\python\python39\lib\site-packages\matplotlib\backends\backend_agg.py:446, in FigureCanvasAgg._print_pil(self, filename_or_obj, fmt, pil_kwargs, metadata)
#     441 """
#     442 Draw the canvas, then save it using `.image.imsave` (to which
#     443 *pil_kwargs* and *metadata* are forwarded).
#     444 """
#     445 FigureCanvasAgg.draw(self)
# --> 446 mpl.image.imsave(
#     447     filename_or_obj, self.buffer_rgba(), format=fmt, origin="upper",
#     448     dpi=self.figure.dpi, metadata=metadata, pil_kwargs=pil_kwargs)
#
# File c:\users\maste\appdata\local\programs\python\python39\lib\site-packages\matplotlib\image.py:1656, in imsave(fname, arr, vmin, vmax, cmap, format, origin, dpi, metadata, pil_kwargs)
#    1654 pil_kwargs.setdefault("format", format)
#    1655 pil_kwargs.setdefault("dpi", (dpi, dpi))
# -> 1656 image.save(fname, **pil_kwargs)
#
# File c:\users\maste\appdata\local\programs\python\python39\lib\site-packages\PIL\Image.py:2436, in Image.save(self, fp, format, **params)
#    2434         fp = builtins.open(filename, "r+b")
#    2435     else:
# -> 2436         fp = builtins.open(filename, "w+b")
#    2438 try:
#    2439     save_handler(self, fp, filename)
#
# OSError: [Errno 22] Invalid argument: 'McGowan, Miss. Anna "Annie"_wordcloud.png'

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %% [markdown]
# ### Sex 😏

# %%
df["Sex"].unique()
# Out:
# array(['male', 'female'], dtype=object)

# %%
''' Only 2 unique values ( of course) '''
# Out:
# ' Only 2 unique values ( of course) '

# %%
sns.countplot(x=df['Sex'], hue=df['Survived'])
# Out:
# <Axes: xlabel='Sex', ylabel='count'>

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %% [markdown]
# ### Age

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
# Plot a histogram
plt.figure(figsize=(8, 6))
plt.hist(df['Age'], bins=10, color='skyblue', edgecolor='black')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.title('Histogram of Age')
plt.show()

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %% [markdown]
# ### SibSp

# %%
freq_mapping = df['SibSp'].value_counts().sort_index()

# Create a line plot
plt.figure(figsize=(10, 6))
plt.plot(freq_mapping.index, freq_mapping.values, marker='o')
plt.xlabel('SibSp')
plt.ylabel('Frequency')
plt.title('Frequency Mapping of SibSp')
plt.grid(True)
plt.show()

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %% [markdown]
# ### Parch

# %%
freq_mapping = df['Parch'].value_counts().sort_index()

# Create a line plot
plt.figure(figsize=(10, 6))
plt.plot(freq_mapping.index, freq_mapping.values, marker='o')
plt.xlabel('Parch')
plt.ylabel('Frequency')
plt.title('Frequency Mapping of Parch')
plt.grid(True)
plt.show()

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %% [markdown]
# ### Ticket

# %%
df["Ticket"].describe()
# Out:
# count        891
# unique       681
# top       347082
# freq           7
# Name: Ticket, dtype: object

# %%
df["Ticket"].unique()
# Out:
# array(['A/5 21171', 'PC 17599', 'STON/O2. 3101282', '113803', '373450',
#        '330877', '17463', '349909', '347742', '237736', 'PP 9549',
#        '113783', 'A/5. 2151', '347082', '350406', '248706', '382652',
#        '244373', '345763', '2649', '239865', '248698', '330923', '113788',
#        '347077', '2631', '19950', '330959', '349216', 'PC 17601',
#        'PC 17569', '335677', 'C.A. 24579', 'PC 17604', '113789', '2677',
#        'A./5. 2152', '345764', '2651', '7546', '11668', '349253',
#        'SC/Paris 2123', '330958', 'S.C./A.4. 23567', '370371', '14311',
#        '2662', '349237', '3101295', 'A/4. 39886', 'PC 17572', '2926',
#        '113509', '19947', 'C.A. 31026', '2697', 'C.A. 34651', 'CA 2144',
#        '2669', '113572', '36973', '347088', 'PC 17605', '2661',
#        'C.A. 29395', 'S.P. 3464', '3101281', '315151', 'C.A. 33111',
#        'S.O.C. 14879', '2680', '1601', '348123', '349208', '374746',
#        '248738', '364516', '345767', '345779', '330932', '113059',
#        'SO/C 14885', '3101278', 'W./C. 6608', 'SOTON/OQ 392086', '343275',
#        '343276', '347466', 'W.E.P. 5734', 'C.A. 2315', '364500', '374910',
#        'PC 17754', 'PC 17759', '231919', '244367', '349245', '349215',
#        '35281', '7540', '3101276', '349207', '343120', '312991', '349249',
#        '371110', '110465', '2665', '324669', '4136', '2627',
#        'STON/O 2. 3101294', '370369', 'PC 17558', 'A4. 54510', '27267',
#        '370372', 'C 17369', '2668', '347061', '349241',
#        'SOTON/O.Q. 3101307', 'A/5. 3337', '228414', 'C.A. 29178',
#        'SC/PARIS 2133', '11752', '7534', 'PC 17593', '2678', '347081',
#        'STON/O2. 3101279', '365222', '231945', 'C.A. 33112', '350043',
#        '230080', '244310', 'S.O.P. 1166', '113776', 'A.5. 11206',
#        'A/5. 851', 'Fa 265302', 'PC 17597', '35851', 'SOTON/OQ 392090',
#        '315037', 'CA. 2343', '371362', 'C.A. 33595', '347068', '315093',
#        '363291', '113505', 'PC 17318', '111240', 'STON/O 2. 3101280',
#        '17764', '350404', '4133', 'PC 17595', '250653', 'LINE',
#        'SC/PARIS 2131', '230136', '315153', '113767', '370365', '111428',
#        '364849', '349247', '234604', '28424', '350046', 'PC 17610',
#        '368703', '4579', '370370', '248747', '345770', '3101264', '2628',
#        'A/5 3540', '347054', '2699', '367231', '112277',
#        'SOTON/O.Q. 3101311', 'F.C.C. 13528', 'A/5 21174', '250646',
#        '367229', '35273', 'STON/O2. 3101283', '243847', '11813',
#        'W/C 14208', 'SOTON/OQ 392089', '220367', '21440', '349234',
#        '19943', 'PP 4348', 'SW/PP 751', 'A/5 21173', '236171', '347067',
#        '237442', 'C.A. 29566', 'W./C. 6609', '26707', 'C.A. 31921',
#        '28665', 'SCO/W 1585', '367230', 'W./C. 14263',
#        'STON/O 2. 3101275', '2694', '19928', '347071', '250649', '11751',
#        '244252', '362316', '113514', 'A/5. 3336', '370129', '2650',
#        'PC 17585', '110152', 'PC 17755', '230433', '384461', '110413',
#        '112059', '382649', 'C.A. 17248', '347083', 'PC 17582', 'PC 17760',
#        '113798', '250644', 'PC 17596', '370375', '13502', '347073',
#        '239853', 'C.A. 2673', '336439', '347464', '345778', 'A/5. 10482',
#        '113056', '349239', '345774', '349206', '237798', '370373',
#        '19877', '11967', 'SC/Paris 2163', '349236', '349233', 'PC 17612',
#        '2693', '113781', '19988', '9234', '367226', '226593', 'A/5 2466',
#        '17421', 'PC 17758', 'P/PP 3381', 'PC 17485', '11767', 'PC 17608',
#        '250651', '349243', 'F.C.C. 13529', '347470', '29011', '36928',
#        '16966', 'A/5 21172', '349219', '234818', '345364', '28551',
#        '111361', '113043', 'PC 17611', '349225', '7598', '113784',
#        '248740', '244361', '229236', '248733', '31418', '386525',
#        'C.A. 37671', '315088', '7267', '113510', '2695', '2647', '345783',
#        '237671', '330931', '330980', 'SC/PARIS 2167', '2691',
#        'SOTON/O.Q. 3101310', 'C 7076', '110813', '2626', '14313',
#        'PC 17477', '11765', '3101267', '323951', 'C 7077', '113503',
#        '2648', '347069', 'PC 17757', '2653', 'STON/O 2. 3101293',
#        '349227', '27849', '367655', 'SC 1748', '113760', '350034',
#        '3101277', '350052', '350407', '28403', '244278', '240929',
#        'STON/O 2. 3101289', '341826', '4137', '315096', '28664', '347064',
#        '29106', '312992', '349222', '394140', 'STON/O 2. 3101269',
#        '343095', '28220', '250652', '28228', '345773', '349254',
#        'A/5. 13032', '315082', '347080', 'A/4. 34244', '2003', '250655',
#        '364851', 'SOTON/O.Q. 392078', '110564', '376564', 'SC/AH 3085',
#        'STON/O 2. 3101274', '13507', 'C.A. 18723', '345769', '347076',
#        '230434', '65306', '33638', '113794', '2666', '113786', '65303',
#        '113051', '17453', 'A/5 2817', '349240', '13509', '17464',
#        'F.C.C. 13531', '371060', '19952', '364506', '111320', '234360',
#        'A/S 2816', 'SOTON/O.Q. 3101306', '113792', '36209', '323592',
#        '315089', 'SC/AH Basle 541', '7553', '31027', '3460', '350060',
#        '3101298', '239854', 'A/5 3594', '4134', '11771', 'A.5. 18509',
#        '65304', 'SOTON/OQ 3101317', '113787', 'PC 17609', 'A/4 45380',
#        '36947', 'C.A. 6212', '350035', '315086', '364846', '330909',
#        '4135', '26360', '111427', 'C 4001', '382651', 'SOTON/OQ 3101316',
#        'PC 17473', 'PC 17603', '349209', '36967', 'C.A. 34260', '226875',
#        '349242', '12749', '349252', '2624', '2700', '367232',
#        'W./C. 14258', 'PC 17483', '3101296', '29104', '2641', '2690',
#        '315084', '113050', 'PC 17761', '364498', '13568', 'WE/P 5735',
#        '2908', '693', 'SC/PARIS 2146', '244358', '330979', '2620',
#        '347085', '113807', '11755', '345572', '372622', '349251',
#        '218629', 'SOTON/OQ 392082', 'SOTON/O.Q. 392087', 'A/4 48871',
#        '349205', '2686', '350417', 'S.W./PP 752', '11769', 'PC 17474',
#        '14312', 'A/4. 20589', '358585', '243880', '2689',
#        'STON/O 2. 3101286', '237789', '13049', '3411', '237565', '13567',
#        '14973', 'A./5. 3235', 'STON/O 2. 3101273', 'A/5 3902', '364848',
#        'SC/AH 29037', '248727', '2664', '349214', '113796', '364511',
#        '111426', '349910', '349246', '113804', 'SOTON/O.Q. 3101305',
#        '370377', '364512', '220845', '31028', '2659', '11753', '350029',
#        '54636', '36963', '219533', '349224', '334912', '27042', '347743',
#        '13214', '112052', '237668', 'STON/O 2. 3101292', '350050',
#        '349231', '13213', 'S.O./P.P. 751', 'CA. 2314', '349221', '8475',
#        '330919', '365226', '349223', '29751', '2623', '5727', '349210',
#        'STON/O 2. 3101285', '234686', '312993', 'A/5 3536', '19996',
#        '29750', 'F.C. 12750', 'C.A. 24580', '244270', '239856', '349912',
#        '342826', '4138', '330935', '6563', '349228', '350036', '24160',
#        '17474', '349256', '2672', '113800', '248731', '363592', '35852',
#        '348121', 'PC 17475', '36864', '350025', '223596', 'PC 17476',
#        'PC 17482', '113028', '7545', '250647', '348124', '34218', '36568',
#        '347062', '350048', '12233', '250643', '113806', '315094', '36866',
#        '236853', 'STON/O2. 3101271', '239855', '28425', '233639',
#        '349201', '349218', '16988', '376566', 'STON/O 2. 3101288',
#        '250648', '113773', '335097', '29103', '392096', '345780',
#        '349204', '350042', '29108', '363294', 'SOTON/O2 3101272', '2663',
#        '347074', '112379', '364850', '8471', '345781', '350047',
#        'S.O./P.P. 3', '2674', '29105', '347078', '383121', '36865',
#        '2687', '113501', 'W./C. 6607', 'SOTON/O.Q. 3101312', '374887',
#        '3101265', '12460', 'PC 17600', '349203', '28213', '17465',
#        '349244', '2685', '2625', '347089', '347063', '112050', '347087',
#        '248723', '3474', '28206', '364499', '112058', 'STON/O2. 3101290',
#        'S.C./PARIS 2079', 'C 7075', '315098', '19972', '368323', '367228',
#        '2671', '347468', '2223', 'PC 17756', '315097', '392092', '11774',
#        'SOTON/O2 3101287', '2683', '315090', 'C.A. 5547', '349213',
#        '347060', 'PC 17592', '392091', '113055', '2629', '350026',
#        '28134', '17466', '233866', '236852', 'SC/PARIS 2149', 'PC 17590',
#        '345777', '349248', '695', '345765', '2667', '349212', '349217',
#        '349257', '7552', 'C.A./SOTON 34068', 'SOTON/OQ 392076', '211536',
#        '112053', '111369', '370376'], dtype=object)

# %% [markdown]
# ### Fare

# %%
df["Fare"].value_counts()
# Out:
# 8.0500     43
# 13.0000    42
# 7.8958     38
# 7.7500     34
# 26.0000    31
#            ..
# 35.0000     1
# 28.5000     1
# 6.2375      1
# 14.0000     1
# 10.5167     1
# Name: Fare, Length: 248, dtype: int64

# %%
df["Fare"].describe()
# Out:
# count    891.000000
# mean      32.204208
# std       49.693429
# min        0.000000
# 25%        7.910400
# 50%       14.454200
# 75%       31.000000
# max      512.329200
# Name: Fare, dtype: float64

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
# Function to check if a value can be converted to an integer
def is_convertible_to_int(value):
    try:
        int(value)
        return True
    except ValueError:
        return False

# Apply the function to the column and create a new column
df['ConvertibleToInt'] = df['Fare'].apply(is_convertible_to_int)

# Create a countplot
plt.figure(figsize=(8, 6))
sns.countplot(x='ConvertibleToInt', data=df)
plt.xlabel('Convertible to Int')
plt.ylabel('Count')
plt.title('Count of Values Convertible to Int vs Not Convertible')
plt.show()

df.drop("ConvertibleToInt" , axis = 1 , inplace = True)

# %% [markdown]
# ### Cabin

# %%
# Create a bar plot
plt.figure(figsize=(8, 6))
sns.countplot(x='Cabin', data=df)
plt.xlabel('Cabin')
plt.ylabel('Frequency')
plt.title('Frequency of String Values')
plt.xticks(rotation=45)
plt.show()

# %%
'''As you can see, its a mess xd'''
# Out:
# 'As you can see, its a mess xd'

# %% [markdown]
# ### Embarked

# %%
df["Embarked"].unique()
# Out:
# array(['S', 'C', 'Q', nan], dtype=object)

# %%
class_counts = df['Embarked'].value_counts()

plt.figure(figsize=(8, 8))
plt.pie(class_counts, labels=class_counts.index, autopct='%1.1f%%', startangle=90)
plt.axis('equal')
plt.title('Passenger Class Distribution')
plt.show()

# %% [markdown]
# ## Feature Engineering

# %%
#rename id, drop name
df["Id"] = df["PassengerId"]
df.drop("PassengerId" , axis = 1 , inplace = True)
df.drop("Name" , axis =1  , inplace = True)

# %%
# rearranging the columns 
df = df[['Id', 'Pclass', 'Sex', 'Age', 'SibSp', 'Parch', 'Fare', 'Embarked' , "Survived"]]

# %% [markdown]
# ### LabelEncoding on -> Embarked , Sex

# %%
from sklearn.preprocessing import LabelEncoder

df['Embarked'] = df['Embarked'].fillna("0")
encoder = LabelEncoder()
df['Embarked'] = encoder.fit_transform(df['Embarked'])
df["Sex"] = encoder.fit_transform(df["Sex"])
# Out:
# C:\Users\maste\AppData\Local\Temp\ipykernel_8004\1137917028.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Embarked'] = df['Embarked'].fillna("0")
# C:\Users\maste\AppData\Local\Temp\ipykernel_8004\1137917028.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Embarked'] = encoder.fit_transform(df['Embarked'])
# C:\Users\maste\AppData\Local\Temp\ipykernel_8004\1137917028.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Sex"] = encoder.fit_transform(df["Sex"])

# %% [markdown]
# ### Dealing with NULL values

# %%
df.isnull().sum()
# Out:
# Id            0
# Pclass        0
# Sex           0
# Age         177
# SibSp         0
# Parch         0
# Fare          0
# Embarked      0
# Survived      0
# dtype: int64

# %%
# Replacing the null values of age with the mean 
mean_age = df['Age'].mean()
df['Age'] = df['Age'].fillna(mean_age)
# Out:
# C:\Users\maste\AppData\Local\Temp\ipykernel_8004\399185683.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Age'] = df['Age'].fillna(mean_age)

# %% [markdown]
# ## Feature Selection

# %%
df.columns
# Out:
# Index(['Id', 'Pclass', 'Sex', 'Age', 'SibSp', 'Parch', 'Fare', 'Embarked',
#        'Survived'],
#       dtype='object')

# %%
from scipy.stats import pearsonr

correlations = {}
for column in df.columns[:-1]:  # Exclude the last column (Survived)
    corr, _ = pearsonr(df[column], df['Survived'])
    correlations[column] = corr

print("Pearson correlation coefficients: \n")

for column, corr in correlations.items():
    print(f"{column}: {corr}")
# Out:
# Pearson correlation coefficients:
#
# Id: -0.0050066607670664984
# Pclass: -0.3384810359610152
# Sex: -0.5433513806577559
# Age: -0.06980851528714312
# SibSp: -0.03532249888573563
# Parch: 0.08162940708348347
# Fare: 0.25730652238496243
# Embarked: -0.17650922516888265

# %%
''' HEATMAP OF PEARSON CORRELATION'''

corr_matrix = df.corr()

# Create a heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', vmin=-1, vmax=1)
plt.title('Pearson Correlation Heatmap')
plt.show()

# %%
df.columns
# Out:
# Index(['Id', 'Pclass', 'Sex', 'Age', 'SibSp', 'Parch', 'Fare', 'Embarked',
#        'Survived'],
#       dtype='object')

# %%
'''Chi-square test to check the degree of independence with respect to our Survived column'''
from scipy.stats import chi2_contingency

print(f"Chi-square statistic for: \n")
columns = ['Pclass', 'Sex', 'Age', 'SibSp', 'Parch', 'Fare', 'Embarked']
results = []

for col in columns:
    contingency_table = pd.crosstab(df[col], df['Survived'])
    chi2, p_value, _, _ = chi2_contingency(contingency_table)
    results.append({'Column': col, 'Chi-square': chi2, 'P-value': p_value})
    print(f"{col}: {chi2} ")
    print(f"P-value for {col}: {p_value} \n")

# Create a DataFrame from the results
results_df = pd.DataFrame(results)

# Statistical representation using a table
print(results_df)

# Graphical representation using a bar plot
plt.figure(figsize=(12, 6))
sns.barplot(x='Column', y='Chi-square', data=results_df, palette='viridis')
plt.title('Chi-square statistic for each column')
plt.xlabel('Column')
plt.ylabel('Chi-square')
plt.xticks(rotation=45)
plt.show()
# Out:
# Chi-square statistic for:
#
# Pclass: 102.88898875696056
# P-value for Pclass: 4.549251711298793e-23
#
# Sex: 260.71702016732104
# P-value for Sex: 1.1973570627755645e-58
#
# Age: 113.79431126384412
# P-value for Age: 0.03358316459333609
#
# SibSp: 37.2717929152043
# P-value for SibSp: 1.5585810465902147e-06
#
# Parch: 27.925784060236168
# P-value for Parch: 9.703526421039996e-05
#
# Fare: 425.8083805791106
# P-value for Fare: 1.1647635739939964e-11
#
# Embarked: 29.670614191394378
# P-value for Embarked: 1.6187188009450462e-06
#
#      Column  Chi-square       P-value
# 0    Pclass  102.888989  4.549252e-23
# 1       Sex  260.717020  1.197357e-58
# 2       Age  113.794311  3.358316e-02
# 3     SibSp   37.271793  1.558581e-06
# 4     Parch   27.925784  9.703526e-05
# 5      Fare  425.808381  1.164764e-11
# 6  Embarked   29.670614  1.618719e-06
# C:\Users\maste\AppData\Local\Temp\ipykernel_8004\2748565462.py:23: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Column', y='Chi-square', data=results_df, palette='viridis')

# %%
'''
Was planning to set up a threshold to filter out columns. However, since these degree of coefficients are too low, its best to keep all these
factors altogether...
Except for id, let's kill it :)
'''
# Out:
# "\nWas planning to set up a threshold to filter out columns. However, since these degree of coefficients are too low, its best to keep all these\nfactors altogether...\nExcept for id, let's kill it :)\n"

# %%
df.columns
# Out:
# Index(['Id', 'Pclass', 'Sex', 'Age', 'SibSp', 'Parch', 'Fare', 'Embarked',
#        'Survived'],
#       dtype='object')

# %%
df.drop("Id" , axis = 1 , inplace = True)
# Out:
# C:\Users\maste\AppData\Local\Temp\ipykernel_8004\3111040356.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop("Id" , axis = 1 , inplace = True)

# %% [markdown]
# ## Model Building

# %%
X = df.drop("Survived" , axis = 1)
Y = df[["Survived"]]

# %%
# Train test split ratio -> 15%
# random statae 42

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.15, random_state=42)

# %%
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (757, 7)
# (134, 7)
# (757, 1)
# (134, 1)

# %%
X_train.head()
# Out:
#      Pclass  Sex        Age  SibSp  Parch      Fare  Embarked
# 599       1    1  49.000000      1      0   56.9292         1
# 830       3    0  15.000000      1      0   14.4542         1
# 306       1    0  29.699118      0      0  110.8833         1
# 231       3    1  29.000000      0      0    7.7750         3
# 845       3    1  42.000000      0      0    7.5500         3

# %%
X_test.head()
# Out:
#      Pclass  Sex        Age  SibSp  Parch     Fare  Embarked
# 709       3    1  29.699118      1      1  15.2458         1
# 439       2    1  31.000000      0      0  10.5000         3
# 840       3    1  20.000000      0      0   7.9250         3
# 720       2    0   6.000000      0      1  33.0000         3
# 39        3    0  14.000000      1      0  11.2417         1

# %%
y_train.head()
# Out:
#      Survived
# 599         1
# 830         1
# 306         1
# 231         0
# 845         0

# %%
y_test.head()
# Out:
#      Survived
# 709         1
# 439         0
# 840         0
# 720         1
# 39          1

# %%
X_train = X_train.values
y_train = y_train.values
X_test = X_test.values
y_test = y_test.values

# %%
X_train = X_train.T
y_train = y_train.reshape(1, X_train.shape[1])

X_test = X_test.T
y_test = y_test.reshape(1, X_test.shape[1])

# %%
print("Shape of X_train : ", X_train.shape)
print("Shape of Y_train : ", y_train.shape)
print("Shape of X_test : ", X_test.shape)
print("Shape of Y_test : ", y_test.shape)
# Out:
# Shape of X_train :  (7, 757)
# Shape of Y_train :  (1, 757)
# Shape of X_test :  (7, 134)
# Shape of Y_test :  (1, 134)

# %% [markdown]
# # Logistic Regression Model

# %%
def sigmoid(x):
    return 1/(1 + np.exp(-x))

# %%
def model(X, Y, learning_rate, iterations):
    
    m = X_train.shape[1]
    n = X_train.shape[0]
    
    W = np.zeros((n,1))
    B = 0
    
    cost_list = []
    
    for i in range(iterations):
        
        Z = np.dot(W.T, X) + B
        A = sigmoid(Z)
        
        # cost function
        cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
        
        # Gradient Descent
        dW = (1/m)*np.dot(A-Y, X.T)
        dB = (1/m)*np.sum(A - Y)
        
        W = W - learning_rate*dW.T
        B = B - learning_rate*dB
        
        # Keeping track of our cost function value
        cost_list.append(cost)
        
        if(i%(iterations/10) == 0):
            print("cost after ", i, "iteration is : ", cost)
        
    return W, B, cost_list

# %%
iterations = 900000
learning_rate = 0.0099
W, B, cost_list = model(X_train, y_train, learning_rate = learning_rate, iterations = iterations)
# Out:
# cost after  0 iteration is :  0.6931471805599453
# C:\Users\maste\AppData\Local\Temp\ipykernel_8004\281180597.py:17: RuntimeWarning: divide by zero encountered in log
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# C:\Users\maste\AppData\Local\Temp\ipykernel_8004\281180597.py:17: RuntimeWarning: invalid value encountered in multiply
#   cost = -(1/m)*np.sum( Y*np.log(A) + (1-Y)*np.log(1-A))
# cost after  90000 iteration is :  0.6411690401214123
# cost after  180000 iteration is :  0.6315497734653395
# cost after  270000 iteration is :  0.6300512353774039
# cost after  360000 iteration is :  0.6297940826355766
# cost after  450000 iteration is :  0.6297491545061218
# cost after  540000 iteration is :  0.6297412799667517
# cost after  630000 iteration is :  0.6297398990284533
# cost after  720000 iteration is :  0.6297396568330514
# cost after  810000 iteration is :  0.6297396143549618

# %% [markdown]
# ##### Testing Model Accuracy

# %%
def accuracy(X, Y, W, B):
    
    Z = np.dot(W.T, X) + B
    A = sigmoid(Z)
    
    A = A > 0.5
    
    A = np.array(A, dtype = 'int64')
    
    acc = (1 - np.sum(np.absolute(A - Y))/Y.shape[1])*100
    
    print("Accuracy of the model is : ", round(acc, 2), "%")

# %%
accuracy(X_test, y_test, W, B)
# Out:
# Accuracy of the model is :  82.09 %

# %% [markdown]
# ## Support Vector Machine

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X.values, Y.values, test_size=0.15, random_state=42)

# %%
class SVM:
    def __init__(self, C=1.0):
        self.C = C
        self.w = 0
        self.b = 0

    # Hinge Loss Function / Calculation
    def hingeloss(self, w, b, x, y):
        # Regularizer term
        reg = 0.5 * (w * w)

        for i in range(x.shape[0]):
            # Optimization term
            opt_term = y[i] * ((np.dot(w, x[i])) + b)

            # calculating loss
            loss = reg + self.C * max(0, 1 - opt_term)
        return loss[0][0]

    def fit(self, X, Y, batch_size=100, learning_rate=0.03, epochs=1000):
        # The number of features in X
        number_of_features = X.shape[1]

        # The number of Samples in X
        number_of_samples = X.shape[0]

        c = self.C

        # Creating ids from 0 to number_of_samples - 1
        ids = np.arange(number_of_samples)

        # Shuffling the samples randomly
        np.random.shuffle(ids)

        # creating an array of zeros
        w = np.zeros((1, number_of_features))
        b = 0
        losses = []

        # Gradient Descent logic
        for i in range(epochs):
            # Calculating the Hinge Loss
            l = self.hingeloss(w, b, X, Y)

            # Appending all losses
            losses.append(l)

            # Starting from 0 to the number of samples with batch_size as interval
            for batch_initial in range(0, number_of_samples, batch_size):
                gradw = 0
                gradb = 0

                for j in range(batch_initial, batch_initial + batch_size):
                    if j < number_of_samples:
                        x = ids[j]
                        ti = Y[x] * (np.dot(w, X[x].T) + b)

                        if ti > 1:
                            gradw += 0
                            gradb += 0
                        else:
                            # Calculating the gradients

                            # w.r.t w
                            gradw += c * Y[x] * X[x]
                            # w.r.t b
                            gradb += c * Y[x]

                # Updating weights and bias
                w = w - learning_rate * w + learning_rate * gradw
                b = b + learning_rate * gradb

            print(f"Epoch {i + 1}/{epochs}, Loss: {l}")

        self.w = w
        self.b = b

        return self.w, self.b, losses

    def predict(self, X):
        prediction = np.dot(X, self.w[0]) + self.b  # w.x + b
        return np.sign(prediction)

# %%
clf = SVM()

# Fit the classifier
w, b, losses = clf.fit(X_train, y_train)

# Calculate training data accuracy
predictions = clf.predict(X_train)
accuracy = np.mean(predictions == y_train)
print("Training data accuracy:", accuracy)

predictions_test = clf.predict(X_test)
accuracy = np.mean(predictions_test == y_test)
print("Testing data accuracy:", accuracy)
# Out:
# Epoch 1/1000, Loss: 1.0
# Epoch 2/1000, Loss: 2.5229364680601054
# Epoch 3/1000, Loss: 1.935469289497478
# Epoch 4/1000, Loss: 1.5746154287759688
# Epoch 5/1000, Loss: 1.3529596264616666
# Epoch 6/1000, Loss: 1.2168067400789035
# Epoch 7/1000, Loss: 1.1331743321888013
# Epoch 8/1000, Loss: 1.0818028200944245
# Epoch 9/1000, Loss: 1.050247681106551
# Epoch 10/1000, Loss: 1.030864821697727
# Epoch 11/1000, Loss: 1.0189588294913032
# Epoch 12/1000, Loss: 1.011645530280409
# Epoch 13/1000, Loss: 1.0071533095212517
# Epoch 14/1000, Loss: 1.0043939465077782
# Epoch 15/1000, Loss: 1.0026989976955223
# Epoch 16/1000, Loss: 1.001657869195162
# Epoch 17/1000, Loss: 1.0010183522100915
# Epoch 18/1000, Loss: 1.0006255265655606
# Epoch 19/1000, Loss: 1.0003842319782335
# Epoch 20/1000, Loss: 1.0002360158964072
# Epoch 21/1000, Loss: 1.0001449736266435
# Epoch 22/1000, Loss: 1.0000890505798214
# Epoch 23/1000, Loss: 1.0000546996439983
# Epoch 24/1000, Loss: 1.000033599456169
# Epoch 25/1000, Loss: 1.0000206385887063
# Epoch 26/1000, Loss: 1.0000126773285152
# Epoch 27/1000, Loss: 1.0000077870953565
# Epoch 28/1000, Loss: 1.0000047832517727
# Epoch 29/1000, Loss: 1.0000029381298767
# Epoch 30/1000, Loss: 1.0000018047570112
# Epoch 31/1000, Loss: 1.0000011085785878
# Epoch 32/1000, Loss: 1.0000006809484476
# Epoch 33/1000, Loss: 1.0000004182750717
# Epoch 34/1000, Loss: 1.000000256926991
# Epoch 35/1000, Loss: 1.0000001578183428
# Epoch 36/1000, Loss: 1.0000000969404936
# Epoch 37/1000, Loss: 1.0000000595460525
# Epoch 38/1000, Loss: 1.0000000365763801
# Epoch 39/1000, Loss: 1.0000000224671752
# Epoch 40/1000, Loss: 1.0000000138005445
# Epoch 41/1000, Loss: 1.0000000084770349
# Epoch 42/1000, Loss: 1.0000000052070497
# Epoch 43/1000, Loss: 1.0000000031984493
# Epoch 44/1000, Loss: 1.000000001964659
# Epoch 45/1000, Loss: 1.000000001206799
# Epoch 46/1000, Loss: 1.0000000007412808
# Epoch 47/1000, Loss: 1.0000000004553344
# Epoch 48/1000, Loss: 1.0000000002796907
# Epoch 945/1000, Loss: 1.0
# Epoch 946/1000, Loss: 1.0
# Epoch 947/1000, Loss: 1.0
# Epoch 948/1000, Loss: 1.0
# Epoch 949/1000, Loss: 1.0
# Epoch 950/1000, Loss: 1.0
# Epoch 951/1000, Loss: 1.0
# Epoch 952/1000, Loss: 1.0
# Epoch 953/1000, Loss: 1.0
# Epoch 954/1000, Loss: 1.0
# Epoch 955/1000, Loss: 1.0
# Epoch 956/1000, Loss: 1.0
# Epoch 957/1000, Loss: 1.0
# Epoch 958/1000, Loss: 1.0
# Epoch 959/1000, Loss: 1.0
# Epoch 960/1000, Loss: 1.0
# Epoch 961/1000, Loss: 1.0
# Epoch 962/1000, Loss: 1.0
# Epoch 963/1000, Loss: 1.0
# Epoch 964/1000, Loss: 1.0
# Epoch 965/1000, Loss: 1.0
# Epoch 966/1000, Loss: 1.0
# Epoch 967/1000, Loss: 1.0
# Epoch 968/1000, Loss: 1.0
# Epoch 969/1000, Loss: 1.0
# Epoch 970/1000, Loss: 1.0
# Epoch 971/1000, Loss: 1.0
# Epoch 972/1000, Loss: 1.0
# Epoch 973/1000, Loss: 1.0
# Epoch 974/1000, Loss: 1.0
# Epoch 975/1000, Loss: 1.0
# Epoch 976/1000, Loss: 1.0
# Epoch 977/1000, Loss: 1.0
# Epoch 978/1000, Loss: 1.0
# Epoch 979/1000, Loss: 1.0
# Epoch 980/1000, Loss: 1.0
# Epoch 981/1000, Loss: 1.0
# Epoch 982/1000, Loss: 1.0
# Epoch 983/1000, Loss: 1.0
# Epoch 984/1000, Loss: 1.0
# Epoch 985/1000, Loss: 1.0
# Epoch 986/1000, Loss: 1.0
# Epoch 987/1000, Loss: 1.0
# Epoch 988/1000, Loss: 1.0
# Epoch 989/1000, Loss: 1.0
# Epoch 990/1000, Loss: 1.0
# Epoch 991/1000, Loss: 1.0
# Epoch 992/1000, Loss: 1.0
# Epoch 993/1000, Loss: 1.0
# Epoch 994/1000, Loss: 1.0
# Epoch 995/1000, Loss: 1.0
# Epoch 996/1000, Loss: 1.0
# Epoch 997/1000, Loss: 1.0
# Epoch 998/1000, Loss: 1.0
# Epoch 999/1000, Loss: 1.0
# Epoch 1000/1000, Loss: 1.0
# Training data accuracy: 0.37780713342140027
# Testing data accuracy: 0.417910447761194

# %% [markdown]
# ###### Training data accuracy: 0.37780713342140027
# ###### Testing data accuracy: 0.417910447761194

# %% [markdown]
# #### Accuracies weren't upto the mark so also did using Scikit-learn

# %%
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score

svc_model = SVC(kernel='linear')

# Training the model
svc_model.fit(X_train, y_train)

# Making predictions on the training set
y_train_pred = svc_model.predict(X_train)

# Making predictions on the test set
y_test_pred = svc_model.predict(X_test)

# Calculating accuracy for training and test data
train_accuracy = accuracy_score(y_train, y_train_pred)
test_accuracy = accuracy_score(y_test, y_test_pred)

print("Training Accuracy:", train_accuracy)
print("Test Accuracy:", test_accuracy)
# Out:
# c:\users\maste\appdata\local\programs\python\python39\lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Training Accuracy: 0.7873183619550859
# Test Accuracy: 0.7835820895522388

# %% [markdown]
# ## Decision Tree From Scratch

# %%
import numpy as np
from collections import Counter

class Node:
    def __init__(self, feature=None, threshold=None, left=None, right=None, *, value=None):
        self.feature = feature
        self.threshold = threshold
        self.left = left
        self.right = right
        self.value = value

    def is_leaf_node(self):
        return self.value is not None


class DecisionTree:
    def __init__(self, min_samples_split=2, max_depth=100, n_features=None):
        self.min_samples_split = min_samples_split
        self.max_depth = max_depth
        self.n_features = n_features
        self.root = None

    def fit(self, X, y):
        self.n_features = X.shape[1] if not self.n_features else min(X.shape[1], self.n_features)
        print("Growing the tree...\n")
        self.root = self._grow_tree(X, y, depth=0)
        print("\nTree growth completed.")

    def _grow_tree(self, X, y, depth):
        n_samples, n_feats = X.shape
        n_labels = len(np.unique(y))

        # check the stopping criteria
        if (depth >= self.max_depth or n_labels == 1 or n_samples < self.min_samples_split):
            leaf_value = self._most_common_label(y)
            print(f"{'   ' * depth} Leaf Node: Value = {leaf_value}")
            return Node(value=leaf_value)

        feat_idxs = np.random.choice(n_feats, self.n_features, replace=False)

        # find the best split
        best_feature, best_thresh = self._best_split(X, y, feat_idxs)
        print(f"{'   ' * depth} Internal Node: Splitting at feature {best_feature} with threshold {best_thresh}")

        # create child nodes
        left_idxs, right_idxs = self._split(X[:, best_feature], best_thresh)
        left = self._grow_tree(X[left_idxs, :], y[left_idxs], depth + 1)
        right = self._grow_tree(X[right_idxs, :], y[right_idxs], depth + 1)
        return Node(best_feature, best_thresh, left, right)

    def _best_split(self, X, y, feat_idxs):
        best_gain = -1
        split_idx, split_threshold = None, None

        for feat_idx in feat_idxs:
            X_column = X[:, feat_idx]
            thresholds = np.unique(X_column)

            for thr in thresholds:
                # calculate the information gain
                gain = self._information_gain(y, X_column, thr)

                if gain > best_gain:
                    best_gain = gain
                    split_idx = feat_idx
                    split_threshold = thr

        return split_idx, split_threshold

    def _information_gain(self, y, X_column, threshold):
        # parent entropy
        parent_entropy = self._entropy(y)

        # create children
        left_idxs, right_idxs = self._split(X_column, threshold)

        if len(left_idxs) == 0 or len(right_idxs) == 0:
            return 0

        # calculate the weighted avg. entropy of children
        n = len(y)
        n_l, n_r = len(left_idxs), len(right_idxs)
        e_l, e_r = self._entropy(y[left_idxs]), self._entropy(y[right_idxs])
        child_entropy = (n_l / n) * e_l + (n_r / n) * e_r

        # calculate the IG
        information_gain = parent_entropy - child_entropy
        return information_gain

    def _split(self, X_column, split_thresh):
        left_idxs = np.argwhere(X_column <= split_thresh).flatten()
        right_idxs = np.argwhere(X_column > split_thresh).flatten()
        return left_idxs, right_idxs

    def _entropy(self, y):
        hist = np.bincount(y)
        ps = hist / len(y)
        return -np.sum([p * np.log(p) for p in ps if p > 0])

    def _most_common_label(self, y):
        counter = Counter(y)
        value = counter.most_common(1)[0][0]
        return value

    def predict(self, X):
        return np.array([self._traverse_tree(x, self.root) for x in X])

    def _traverse_tree(self, x, node):
        if node.is_leaf_node():
            return node.value

        if x[node.feature] <= node.threshold:
            return self._traverse_tree(x, node.left)
        return self._traverse_tree(x, node.right)

# %%
X_train, X_test, y_train, y_test = train_test_split(X.values, Y.values, test_size=0.15, random_state=42)
y_train = y_train.flatten()

# %%
# Check the shape and type of X_train and y_train
print("Shape of X_train:", X_train.shape)
print("Type of X_train:", type(X_train))
print("Shape of y_train:", y_train.shape)
print("Type of y_train:", type(y_train))

print()
print()

# Create and train the decision tree
tree = DecisionTree(min_samples_split=2, max_depth=5, n_features=None)
tree.fit(X_train, y_train)

# Predict on training and test data
y_train_pred = tree.predict(X_train)
y_test_pred = tree.predict(X_test)

# Calculate training and test data accuracy
train_accuracy = accuracy_score(y_train, y_train_pred)
test_accuracy = accuracy_score(y_test, y_test_pred)

print("Training Accuracy:", train_accuracy)
print("Test Accuracy:", test_accuracy)
# Out:
# Shape of X_train: (757, 7)
# Type of X_train: <class 'numpy.ndarray'>
# Shape of y_train: (757,)
# Type of y_train: <class 'numpy.ndarray'>
#
#
# Growing the tree...
#
#  Internal Node: Splitting at feature 1 with threshold 0.0
#     Internal Node: Splitting at feature 0 with threshold 2.0
#        Internal Node: Splitting at feature 2 with threshold 2.0
#           Internal Node: Splitting at feature 4 with threshold 1.0
#              Leaf Node: Value = 1
#              Leaf Node: Value = 0
#           Internal Node: Splitting at feature 5 with threshold 28.7125
#              Internal Node: Splitting at feature 5 with threshold 27.75
#                 Leaf Node: Value = 1
#                 Leaf Node: Value = 0
#              Internal Node: Splitting at feature 4 with threshold 1.0
#                 Leaf Node: Value = 1
#                 Leaf Node: Value = 1
#        Internal Node: Splitting at feature 5 with threshold 23.25
#           Internal Node: Splitting at feature 5 with threshold 7.7375
#              Internal Node: Splitting at feature 5 with threshold 6.75
#                 Leaf Node: Value = 0
#                 Leaf Node: Value = 1
#              Internal Node: Splitting at feature 5 with threshold 15.2458
#                 Leaf Node: Value = 0
#                 Leaf Node: Value = 1
#           Internal Node: Splitting at feature 4 with threshold 0.0
#              Leaf Node: Value = 1
#              Internal Node: Splitting at feature 5 with threshold 31.275
#                 Leaf Node: Value = 0
#                 Leaf Node: Value = 0
#     Internal Node: Splitting at feature 2 with threshold 6.0
#        Internal Node: Splitting at feature 3 with threshold 2.0
#           Leaf Node: Value = 1
#           Internal Node: Splitting at feature 4 with threshold 1.0
#              Leaf Node: Value = 0
#              Internal Node: Splitting at feature 2 with threshold 1.0
#                 Leaf Node: Value = 0
#                 Leaf Node: Value = 1
#        Internal Node: Splitting at feature 5 with threshold 26.25
#           Internal Node: Splitting at feature 2 with threshold 12.0
#              Internal Node: Splitting at feature 5 with threshold 15.9
#                 Leaf Node: Value = 1
#                 Leaf Node: Value = 0
#              Internal Node: Splitting at feature 2 with threshold 32.0
#                 Leaf Node: Value = 0
#                 Leaf Node: Value = 0
#           Internal Node: Splitting at feature 3 with threshold 2.0
#              Internal Node: Splitting at feature 5 with threshold 26.3875
#                 Leaf Node: Value = 1
#                 Leaf Node: Value = 0
#              Leaf Node: Value = 0
#
# Tree growth completed.
# Training Accuracy: 0.8480845442536328
# Test Accuracy: 0.7686567164179104

# %% [markdown]
# ###### Training data accuracy:  0.8480845442536328
# ###### Testing data accuracy: 0.7686567164179104

# %%
## YEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEE DONE :)

# %% [markdown]
# # Made By: Kartikey Bartwal
# ### https://www.linkedin.com/in/kartikey-bartwal-649088238/
# ### https://www.instagram.com/_._mr.kb_._/?next=%2F
# ### https://twitter.com/__mr__kb__
